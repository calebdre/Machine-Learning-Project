# %%
# %matplotlib inline

from time import time

from math import sqrt, floor
import numpy as np

import matplotlib.pyplot as plt
plt.style.use = "default"

import pandas as pd
pd.options.display.float_format = '{:.3f}'.format

from IPython.core.debugger import set_trace

import sys
sys.path.append('../../')
from rfc import RandomForest
from Experiment import Experiment

# %%
train = pd.read_csv("cleaned_train.csv")
labels = pd.read_csv("cleaned_label.csv")

# %%
train = train.drop(train.columns[0], axis=1)
labels = labels.drop(labels.columns[0], axis=1) 
labels = labels.rename(columns={"9": "label"})

# %%
train.describe()
# Out:
#              2        1        5        4      5.1      5.2        3      3.1  \
# count 6299.000 6299.000 6299.000 6299.000 6299.000 6299.000 6299.000 6299.000
# mean     1.549    3.013    3.419    3.814    3.774    4.175    1.565    2.855
# std      0.498    1.801    1.639    1.219    2.530    1.161    0.750    1.538
# min      1.000    1.000    1.000    1.000    1.000    1.000    1.000    1.000
# 25%      1.000    1.000    2.000    3.000    1.000    4.000    1.000    2.000
# 50%      2.000    3.000    3.000    4.000    3.000    5.000    1.000    2.000
# 75%      2.000    5.000    4.000    5.000    6.000    5.000    2.000    4.000
# max      2.000    5.000    7.000    6.000    9.000    5.000    3.000    9.000
#
#              0      1.1      1.2        7  1.00000000000000e+99
# count 6299.000 6299.000 6299.000 6299.000              6299.000
# mean     0.688    1.804    1.800    5.943                 1.124
# std      1.114    0.748    1.141    1.741                 0.408
# min      0.000    1.000    1.000    1.000                 1.000
# 25%      0.000    1.000    1.000    5.000                 1.000
# 50%      0.000    2.000    1.000    7.000                 1.000
# 75%      1.000    2.000    3.000    7.000                 1.000
# max      9.000    3.000    5.000    8.000                 3.000

# %%
def merge(df, labels):
    return labels.merge(df, left_index=True,right_index=True)

# %%
def mprint(*args):
    for arg in args:
        print(arg)
        print(" ")

# %%
merge(train, labels).groupby("label").describe()
# Out:
#              0                                                  1        ...   \
#          count  mean   std   min   25%   50%   75%   max    count  mean  ...
# label                                                                    ...
# 1     1235.000 1.100 1.296 0.000 0.000 1.000 2.000 8.000 1235.000 4.380  ...
# 2      554.000 0.543 1.123 0.000 0.000 0.000 1.000 9.000  554.000 3.619  ...
# 3      488.000 0.445 0.927 0.000 0.000 0.000 1.000 6.000  488.000 3.434  ...
# 4      566.000 0.422 0.883 0.000 0.000 0.000 0.000 6.000  566.000 3.178  ...
# 5      495.000 0.580 1.088 0.000 0.000 0.000 1.000 7.000  495.000 2.990  ...
# 6      777.000 0.632 1.070 0.000 0.000 0.000 1.000 8.000  777.000 2.555  ...
# 7      677.000 0.693 1.026 0.000 0.000 0.000 1.000 6.000  677.000 2.281  ...
# 8      912.000 0.637 1.032 0.000 0.000 0.000 1.000 9.000  912.000 2.089  ...
# 9      595.000 0.652 1.106 0.000 0.000 0.000 1.000 9.000  595.000 1.973  ...
#
#         5.2              7
#         75%   max    count  mean   std   min   25%   50%   75%   max
# label
# 1     5.000 5.000 1235.000 5.649 1.842 1.000 5.000 7.000 7.000 8.000
# 2     5.000 5.000  554.000 5.702 1.829 1.000 5.000 7.000 7.000 8.000
# 3     5.000 5.000  488.000 5.770 1.713 1.000 5.000 7.000 7.000 8.000
# 4     5.000 5.000  566.000 5.919 1.776 1.000 5.000 7.000 7.000 8.000
# 5     5.000 5.000  495.000 6.030 1.587 1.000 5.000 7.000 7.000 8.000
# 6     5.000 5.000  777.000 5.997 1.697 1.000 5.000 7.000 7.000 8.000
# 7     5.000 5.000  677.000 6.034 1.745 1.000 5.000 7.000 7.000 8.000
# 8     5.000 5.000  912.000 6.178 1.646 1.000 7.000 7.000 7.000 8.000
# 9     5.000 5.000  595.000 6.334 1.599 1.000 7.000 7.000 7.000 8.000
#
# [9 rows x 104 columns]

# %%
init_config_names = ["num_trees", "num_features", "num_sample_rows", "max_tree_depth", "min_split_samples", "bias_class", "bias_amount"]
init_config_values = [   10,          4,           20,              20,                5,                 None,            0]

e = Experiment(train, labels, RandomForest, init_config_names, init_config_values, verbose=True)

# %%
t1 = e.run_trial()
# Out:
# Running trail #1
# ------------------------------------
#
# *************************
#
# Running fold 1 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 4
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 6
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 5
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 8
#
# fold 1 took 6.076445817947388s
#
# *************************
#
# Running fold 2 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
# /usr/local/Cellar/python3/3.5.0/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 2
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 5.2 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 6
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 6
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 1
#
# fold 2 took 6.021426200866699s
#
# *************************
#
# Running fold 3 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 5
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 6
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 7
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.1 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 2
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.1 at depth 1 to be in class 1
#
# fold 3 took 7.631569147109985s
#
# *************************
#
# Running fold 4 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 6
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 3
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 5
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# parsing @ depth 2
#
#
# classified 1.1 at depth 2 to be in class 7
#
#
# parsing @ depth 2
#
#
# classified 5 at depth 2 to be in class 1
#
#
# Done with depth 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
# fold 4 took 9.589590787887573s
#
# *************************
#
# Running fold 5 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 9
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 4
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 8
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
# fold 5 took 10.000520944595337s
#
# *************************
#
# Running fold 6 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 4
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.1 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 5.2 at depth 1 to be in class 4
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 4
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 1
#
# fold 6 took 8.311045169830322s
#
# *************************
#
# Running fold 7 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 3
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 7
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 6
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 6
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 6
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 5
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 4
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 7 took 8.415071964263916s
#
# *************************
#
# Running fold 8 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# parsing @ depth 2
#
#
# classified 5 at depth 2 to be in class 1
#
#
# parsing @ depth 2
#
#
# classified 3.1 at depth 2 to be in class 1
#
#
# Done with depth 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 8
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 4
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.1 at depth 1 to be in class 4
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 8 took 9.121819972991943s
#
# *************************
#
# Running fold 9 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 5.2 at depth 1 to be in class 6
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 2 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 6
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 4 at depth 1 to be in class 6
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 4 at depth 1 to be in class 1
#
# fold 9 took 8.53169298171997s
#
# *************************
#
# Running fold 10 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 3 at depth 1 to be in class 8
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 6
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 8
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 5.2 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.1 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.2 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 0 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 7 at depth 1 to be in class 4
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 10 took 8.413872957229614s

# %%
perf, train_test = e.trial_results()

# %%
perf
# Out:
#    num_trees  num_features  num_sample_rows  max_tree_depth  \
# 0     10.000         4.000           20.000          20.000
# 1     10.000         4.000           20.000          20.000
# 2     10.000         4.000           20.000          20.000
# 3     10.000         4.000           20.000          20.000
# 4     10.000         4.000           20.000          20.000
# 5     10.000         4.000           20.000          20.000
# 6     10.000         4.000           20.000          20.000
# 7     10.000         4.000           20.000          20.000
# 8     10.000         4.000           20.000          20.000
# 9     10.000         4.000           20.000          20.000
#
#    min_split_samples  bias_class  bias_amount  log_loss  class_accuracy  \
# 0              5.000      -1.000        0.000     2.197           0.217
# 1              5.000      -1.000        0.000     2.197           0.176
# 2              5.000      -1.000        0.000     2.197           0.187
# 3              5.000      -1.000        0.000     2.197           0.187
# 4              5.000      -1.000        0.000     2.197           0.213
# 5              5.000      -1.000        0.000     2.197           0.181
# 6              5.000      -1.000        0.000     2.197           0.127
# 7              5.000      -1.000        0.000     2.197           0.198
# 8              5.000      -1.000        0.000     2.197           0.219
# 9              5.000      -1.000        0.000     2.197           0.189
#
#    precision  recall  f1-score  support  trial_num
# 0      0.047   0.217     0.078      nan      1.000
# 1      0.031   0.176     0.053      nan      1.000
# 2      0.035   0.187     0.059      nan      1.000
# 3      0.035   0.187     0.059      nan      1.000
# 4      0.045   0.213     0.075      nan      1.000
# 5      0.033   0.181     0.055      nan      1.000
# 6      0.016   0.127     0.029      nan      1.000
# 7      0.039   0.198     0.066      nan      1.000
# 8      0.048   0.219     0.079      nan      1.000
# 9      0.036   0.189     0.060      nan      1.000

# %% [markdown]
# # Trial 1 Notes
# I think the number of rows had something to do with it.

# %%
e.tweak("num_sample_rows", 40).tweak("num_features", train.columns.size).tweak("min_split_samples", 2).tweak("num_trees", 20)

# %%
t2 = e.run_trial()
# Out:
# Running trail #11
# ------------------------------------
#
# *************************
#
# Running fold 1 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 5
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 5
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 1 took 174.69338202476501s
#
# *************************
#
# Running fold 2 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
# /usr/local/Cellar/python3/3.5.0/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 5
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 4
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
# fold 2 took 198.34293913841248s
#
# *************************
#
# Running fold 3 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 9
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 2
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
# fold 3 took 196.00404500961304s
#
# *************************
#
# Running fold 4 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 4
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 9
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 2
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
# fold 4 took 183.61101412773132s
#
# *************************
#
# Running fold 5 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 5 took 160.0157859325409s
#
# *************************
#
# Running fold 6 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
# fold 6 took 146.36124801635742s
#
# *************************
#
# Running fold 7 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 4
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 7 took 151.73499488830566s
#
# *************************
#
# Running fold 8 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 8 took 148.6282889842987s
#
# *************************
#
# Running fold 9 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 3
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 2
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 2
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 2
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 7
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
# fold 9 took 147.36570382118225s
#
# *************************
#
# Running fold 10 of 10
#
# *************************
#
#
# *** Creating tree #1 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #2 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #3 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 8
#
#
# *** Creating tree #4 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #5 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #6 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #7 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #8 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #9 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 5
#
#
# *** Creating tree #10 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #11 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 6
#
#
# *** Creating tree #12 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #13 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #14 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #15 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #16 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #17 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #18 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #19 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
#
# *** Creating tree #20 ***
#
#
# parsing @ depth 1
#
#
# classified 1.00000000000000e+99 at depth 1 to be in class 1
#
# fold 10 took 142.22267198562622s

# %%
t2[0]
# Out:
#     num_trees  num_features  num_sample_rows  max_tree_depth  \
# 10     20.000        13.000           40.000          20.000
# 11     20.000        13.000           40.000          20.000
# 12     20.000        13.000           40.000          20.000
# 13     20.000        13.000           40.000          20.000
# 14     20.000        13.000           40.000          20.000
# 15     20.000        13.000           40.000          20.000
# 16     20.000        13.000           40.000          20.000
# 17     20.000        13.000           40.000          20.000
# 18     20.000        13.000           40.000          20.000
# 19     20.000        13.000           40.000          20.000
#
#     min_split_samples  bias_class  bias_amount  log_loss  class_accuracy  \
# 10              2.000      -1.000        0.000     2.197           0.225
# 11              2.000      -1.000        0.000     2.197           0.192
# 12              2.000      -1.000        0.000     2.197           0.186
# 13              2.000      -1.000        0.000     2.197           0.202
# 14              2.000      -1.000        0.000     2.197           0.195
# 15              2.000      -1.000        0.000     2.197           0.195
# 16              2.000      -1.000        0.000     2.197           0.214
# 17              2.000      -1.000        0.000     2.197           0.184
# 18              2.000      -1.000        0.000     2.197           0.192
# 19              2.000      -1.000        0.000     2.197           0.175
#
#     precision  recall  f1-score  support  trial_num
# 10      0.051   0.225     0.083      nan      2.000
# 11      0.037   0.192     0.062      nan      2.000
# 12      0.034   0.186     0.058      nan      2.000
# 13      0.041   0.202     0.068      nan      2.000
# 14      0.038   0.195     0.064      nan      2.000
# 15      0.038   0.195     0.064      nan      2.000
# 16      0.046   0.214     0.076      nan      2.000
# 17      0.034   0.184     0.057      nan      2.000
# 18      0.037   0.192     0.062      nan      2.000
# 19      0.031   0.175     0.052      nan      2.000

# %%
test = pd.read_csv("TestData3.txt", sep='\t', header=None)

# %%
e.experiment_data[-1][0].predict(test).to_csv("predictions3.txt", sep="\t", index=False, header=False)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-546211ade2b2> in <module>()
# ----> 1 e.experiment_data[-1][0].predict(test).to_csv("predictions3.txt", sep="\t", index=False, header=False)
#
# ~/Downloads/dataanalytics/ml-project/rfc.py in predict(self, row)
#      91     def predict(self, row):
#      92         if not isinstance(row, pd.Series):
# ---> 93             raise Exception("`row` must be an instance of Pandas.Series")
#      94
#      95
#
# Exception: `row` must be an instance of Pandas.Series
